# %% [markdown]
# <a href="https://colab.research.google.com/github/ramatsemela8/Project2/blob/main/Untitled105.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
y = 2+5

print(y)
# Out:
# 7
